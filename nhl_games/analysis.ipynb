# %%
from sqlalchemy import create_engine
from sqlalchemy import text

password = '8ad7fpx2!' # input('Enter password: ')

engine = create_engine(f'mysql+mysqlconnector://root:{password}@localhost:3306/nhlStats', echo = True)

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT birthLocationSecondary FROM players"))

for r in result.mappings():
    print(r['birthLocationSecondary'])
# Out:
# 2024-02-03 20:24:11,838 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-02-03 20:24:11,838 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-03 20:24:11,840 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-02-03 20:24:11,841 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-03 20:24:11,843 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-02-03 20:24:11,844 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-02-03 20:24:11,845 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-03 20:24:11,846 INFO sqlalchemy.engine.Engine SELECT birthLocationSecondary FROM players
# 2024-02-03 20:24:11,846 INFO sqlalchemy.engine.Engine [generated in 0.00116s] {}
# 2024-02-03 20:24:11,857 INFO sqlalchemy.engine.Engine ROLLBACK
# Finland
# Ontario
# Manitoba
# Ontario
# Michigan
# Michigan
# Michigan
# Saskatchewan
# Sweden
# Saskatchewan
# Quebec
# Sweden
# Russia
# New York
# Rhode Island
# Alberta
# Ontario
# Ontario
# Minnesota
# Ontario
# ...
